# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
# !pip install getorg --upgrade
import glob
import getorg
from geopy import Nominatim
# Out:
# Requirement already satisfied: getorg in ./.venv/lib/python3.13/site-packages (0.3.1)
# Requirement already satisfied: geopy in ./.venv/lib/python3.13/site-packages (from getorg) (2.4.1)
# Requirement already satisfied: pygithub in ./.venv/lib/python3.13/site-packages (from getorg) (2.5.0)
# Requirement already satisfied: retrying in ./.venv/lib/python3.13/site-packages (from getorg) (1.3.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in ./.venv/lib/python3.13/site-packages (from geopy->getorg) (2.0)
# Requirement already satisfied: pynacl>=1.4.0 in ./.venv/lib/python3.13/site-packages (from pygithub->getorg) (1.5.0)
# Requirement already satisfied: requests>=2.14.0 in ./.venv/lib/python3.13/site-packages (from pygithub->getorg) (2.32.3)
# Requirement already satisfied: pyjwt>=2.4.0 in ./.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (2.10.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./.venv/lib/python3.13/site-packages (from pygithub->getorg) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in ./.venv/lib/python3.13/site-packages (from pygithub->getorg) (2.2.3)
# Requirement already satisfied: Deprecated in ./.venv/lib/python3.13/site-packages (from pygithub->getorg) (1.2.15)
# Requirement already satisfied: six>=1.7.0 in ./.venv/lib/python3.13/site-packages (from retrying->getorg) (1.17.0)
# Requirement already satisfied: cryptography>=3.4.0 in ./.venv/lib/python3.13/site-packages (from pyjwt[crypto]>=2.4.0->pygithub->getorg) (44.0.0)
# Requirement already satisfied: cffi>=1.4.1 in ./.venv/lib/python3.13/site-packages (from pynacl>=1.4.0->pygithub->getorg) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests>=2.14.0->pygithub->getorg) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests>=2.14.0->pygithub->getorg) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./.venv/lib/python3.13/site-packages (from requests>=2.14.0->pygithub->getorg) (2024.12.14)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.venv/lib/python3.13/site-packages (from Deprecated->pygithub->getorg) (1.17.0)
# Requirement already satisfied: pycparser in ./.venv/lib/python3.13/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->pygithub->getorg) (2.22)

# %%
g = glob.glob("*.md")

# %%
geocoder = Nominatim()
location_dict = {}
location = ""
permalink = ""
title = ""
# Out:
# ---------------------------------------------------------------------------
# ConfigurationError                        Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 geocoder = Nominatim()
#       2 location_dict = {}
#       3 location = ""
#
# File ~/Documents/dev/exeter/glewis-unexe.github.io/.venv/lib/python3.13/site-packages/geopy/geocoders/nominatim.py:105, in Nominatim.__init__(self, timeout, proxies, domain, scheme, user_agent, ssl_context, adapter_factory)
#     101 self.domain = domain.strip('/')
#     103 if (self.domain == _DEFAULT_NOMINATIM_DOMAIN
#     104         and self.headers['User-Agent'] in _REJECTED_USER_AGENTS):
# --> 105     raise ConfigurationError(
#     106         'Using Nominatim with default or sample `user_agent` "%s" is '
#     107         'strongly discouraged, as it violates Nominatim\'s ToS '
#     108         'https://operations.osmfoundation.org/policies/nominatim/ '
#     109         'and may possibly cause 403 and 429 HTTP errors. '
#     110         'Please specify a custom `user_agent` with '
#     111         '`Nominatim(user_agent="my-application")` or by '
#     112         'overriding the default `user_agent`: '
#     113         '`geopy.geocoders.options.default_user_agent = "my-application"`.'
#     114         % self.headers['User-Agent']
#     115     )
#     117 self.api = "%s://%s%s" % (self.scheme, self.domain, self.geocode_path)
#     118 self.reverse_api = "%s://%s%s" % (self.scheme, self.domain, self.reverse_path)
#
# ConfigurationError: Using Nominatim with default or sample `user_agent` "geopy/2.4.1" is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`.

# %%
for file in g:
    with open(file, 'r') as f:
        lines = f.read()
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]
                            
           
        location_dict[location] = geocoder.geocode(location)
        print(location, "\n", location_dict[location])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 11
#       7     loc_end = lines_trim.find('"')
#       8     location = lines_trim[:loc_end]
# ---> 11 location_dict[location] = geocoder.geocode(location)
#      12 print(location, "\n", location_dict[location])
#
# NameError: name 'geocoder' is not defined

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 m = getorg.orgmap.create_map_obj()
# ----> 2 getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
#
# NameError: name 'location_dict' is not defined
